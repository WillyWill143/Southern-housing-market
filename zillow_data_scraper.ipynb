# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import pandas as pd

# %%
"""
# Example URL for a for-sale page in California (adjust as needed)
url = "https://www.zillow.com/homes/for_sale/California_rb/"

# Complete headers to mimic a real browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8",
    "Accept-Encoding": "gzip, deflate, br",
    "DNT": "1",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
    "Referer": "https://www.google.com/"
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")
    
    # Option 1: Try to find the script tag with id "__NEXT_DATA__"
    script_tag = soup.find("script", id="__NEXT_DATA__")
    if script_tag and script_tag.string:
        json_text = script_tag.string.strip()
        try:
            data = json.loads(json_text)
            print("Top-level keys in __NEXT_DATA__ JSON:")
            print(list(data.keys()))
        except json.JSONDecodeError as e:
            print("JSON decoding error in __NEXT_DATA__ tag:", e)
            print("First 1000 characters of script tag:")
            print(json_text[:1000])
    else:
        print("No script tag with id '__NEXT_DATA__' found or it is empty.")
        
    # Option 2: If the above didn't work, iterate over all script tags and look for JSON candidates:
    print("\nChecking other script tags for JSON content...\n")
    scripts = soup.find_all("script")
    candidate_found = False
    for script in scripts:
        if script.string:
            text = script.string.strip()
            # A basic check: if it starts with "{" or "[", it might be JSON.
            if text.startswith("{") or text.startswith("["):
                try:
                    candidate = json.loads(text)
                    candidate_found = True
                    print("Found a candidate JSON with keys:", list(candidate.keys()) if isinstance(candidate, dict) else "Top-level type:", type(candidate))
                    # Optionally, print a small portion for inspection:
                    print(json.dumps(candidate, indent=2)[:1000])
                    break  # Remove break if you want to see more candidates
                except json.JSONDecodeError:
                    continue
    if not candidate_found:
        print("No valid JSON candidate found in any script tag.")
else:
    print("Failed to fetch the page. Status code:", response.status_code)
"""

# %%
"""
# Drill down into the JSON structure to find listings
listings = data.get("props", {}) \
               .get("pageProps", {}) \
               .get("searchPageState", {}) \
               .get("cat1", {}) \
               .get("searchResults", {}) \
               .get("listResults", [])

print(f"Found {len(listings)} listings.")

if listings:
    # Inspect the keys of the first listing
    first_listing = listings[0]
    print("Keys in the first listing:")
    print(list(first_listing.keys()))
    
    # For deeper inspection, you can pretty-print a nested object
    if "hdpData" in first_listing and "homeInfo" in first_listing["hdpData"]:
        print("\nKeys in homeInfo:")
        print(list(first_listing["hdpData"]["homeInfo"].keys()))
else:
    print("No listings found in this JSON branch.")
"""

# %%
['price', 'address', 'addresStreet', 'zipcode', 'city', 'state', 'latitude', 'longitude', 'price', 'bathrooms', 
 'bedrooms', 'livingArea', 'homeType', 'homeStatus', 'daysOnZillow', 'isFeatured', 'timeOnZillow', 'isZillowOwned', 'brokerName', 
 'lotAreaValue', 'lotAreaUnit']

# %%
# -----------------------------
# 1. URL Construction for Target States
# -----------------------------
# Mapping full state names to their two-letter lowercase abbreviations as seen in the URL examples.
state_abbr = {
    "Tennessee": "tn",
    "Texas": "tx",
    "Arkansas": "ar",
    "Mississippi": "ms",
    "Louisiana": "la",
    "Alabama": "al"
}

def construct_state_url(state, page_number=1):
    abbr = state_abbr.get(state, state.lower())
    if page_number == 1:
        return f"https://www.zillow.com/{abbr}/"
    else:
        return f"https://www.zillow.com/{abbr}/{page_number}_p/"

# -----------------------------
# 2. Set Headers
# -----------------------------
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8",
    "Accept-Encoding": "gzip, deflate, br",
    "DNT": "1",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
    "Referer": "https://www.google.com/"
}

# -----------------------------
# 3. Fetch Listings JSON from a Given URL
# -----------------------------
def fetch_listings_from_url(url):
    print(f"Fetching URL: {url}")
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch {url} - Status code: {response.status_code}")
        return []
    
    soup = BeautifulSoup(response.text, "html.parser")
    script_tag = soup.find("script", id="__NEXT_DATA__")
    if not script_tag or not script_tag.string:
        print("No __NEXT_DATA__ JSON found on", url)
        return []
    
    try:
        data = json.loads(script_tag.string)
    except json.JSONDecodeError as e:
        print("JSON decode error on", url, e)
        return []
    
    # Drill down to the listings array; the path might be similar to:
    listings = (data.get("props", {})
                    .get("pageProps", {})
                    .get("searchPageState", {})
                    .get("cat1", {})
                    .get("searchResults", {})
                    .get("listResults", []))
    return listings

# -----------------------------
# 4. Collect Listings Across All Target States
# -----------------------------
target_states = ["Tennessee", "Texas", "Arkansas", "Mississippi", "Louisiana", "Alabama"]
target_total = 10000
all_listings = []

for state in target_states:
    print(f"\n--- Scraping listings for state: {state} ---")
    page_number = 1
    while True:
        url = construct_state_url(state, page_number)
        listings = fetch_listings_from_url(url)
        if not listings:
            print(f"No listings returned for {state} on page {page_number}. Moving to next state.")
            break
        all_listings.extend(listings)
        print(f"Total listings collected so far: {len(all_listings)}")
        if len(all_listings) >= target_total:
            break
        page_number += 1
        time.sleep(2)  # Delay between requests
    if len(all_listings) >= target_total:
        break

# Trim if more than target_total
all_listings = all_listings[:target_total]
print(f"\nCollected {len(all_listings)} listings in total.")

# -----------------------------
# 5. Extract Desired Features from Each Listing
# -----------------------------
def extract_features(listing):
    # Get detailed home information from nested hdpData.homeInfo if available.
    home_info = listing.get("hdpData", {}).get("homeInfo", {})
    return {
        "price": listing.get("price"),
        "address": listing.get("address"),
        "addressStreet": listing.get("addressStreet"),
        "zipcode": listing.get("addressZipcode"),
        "city": listing.get("addressCity"),
        "state": listing.get("addressState"),  # or use home_info.get("state")
        "latitude": home_info.get("latitude") or listing.get("latLong", {}).get("latitude"),
        "longitude": home_info.get("longitude") or listing.get("latLong", {}).get("longitude"),
        "bathrooms": listing.get("baths") or home_info.get("bathrooms"),
        "bedrooms": listing.get("beds") or home_info.get("bedrooms"),
        "livingArea": home_info.get("livingArea"),
        "homeType": home_info.get("homeType"),
        "homeStatus": home_info.get("homeStatus"),
        "daysOnZillow": home_info.get("daysOnZillow"),
        "isFeatured": home_info.get("isFeatured"),
        "timeOnZillow": home_info.get("timeOnZillow"),
        "isZillowOwned": listing.get("isZillowOwned"),
        "brokerName": listing.get("brokerName"),
        "lotAreaValue": home_info.get("lotAreaValue"),
        "lotAreaUnit": home_info.get("lotAreaUnit")
    }

extracted_data = [extract_features(listing) for listing in all_listings]
# Out:
# --- Scraping listings for state: Tennessee ---
# Fetching URL: https://www.zillow.com/tn/
# Total listings collected so far: 41
# Fetching URL: https://www.zillow.com/tn/2_p/
# Total listings collected so far: 82
# Fetching URL: https://www.zillow.com/tn/3_p/
# Total listings collected so far: 123
# Fetching URL: https://www.zillow.com/tn/4_p/
# Total listings collected so far: 164
# Fetching URL: https://www.zillow.com/tn/5_p/
# Total listings collected so far: 205
# Fetching URL: https://www.zillow.com/tn/6_p/
# Total listings collected so far: 246
# Fetching URL: https://www.zillow.com/tn/7_p/
# Total listings collected so far: 287
# Fetching URL: https://www.zillow.com/tn/8_p/
# Total listings collected so far: 328
# Fetching URL: https://www.zillow.com/tn/9_p/
# Total listings collected so far: 369
# Fetching URL: https://www.zillow.com/tn/10_p/
# Total listings collected so far: 410
# Fetching URL: https://www.zillow.com/tn/11_p/
# Total listings collected so far: 451
# Fetching URL: https://www.zillow.com/tn/12_p/
# Total listings collected so far: 492
# Fetching URL: https://www.zillow.com/tn/13_p/
# Total listings collected so far: 533
# Fetching URL: https://www.zillow.com/tn/14_p/
# Total listings collected so far: 574
# Fetching URL: https://www.zillow.com/tn/15_p/
# Total listings collected so far: 615
# Fetching URL: https://www.zillow.com/tn/16_p/
# Total listings collected so far: 656
# Fetching URL: https://www.zillow.com/tn/17_p/
# Total listings collected so far: 697
# Fetching URL: https://www.zillow.com/tn/18_p/
# Total listings collected so far: 738
# Fetching URL: https://www.zillow.com/tn/19_p/
# Total listings collected so far: 779
# Fetching URL: https://www.zillow.com/tn/20_p/
# Total listings collected so far: 820
# Fetching URL: https://www.zillow.com/tn/21_p/
# Total listings collected so far: 861
# Fetching URL: https://www.zillow.com/tn/22_p/
# Total listings collected so far: 902
# Fetching URL: https://www.zillow.com/tn/23_p/
# Total listings collected so far: 943
# Fetching URL: https://www.zillow.com/tn/24_p/
# Total listings collected so far: 984
# Fetching URL: https://www.zillow.com/tn/25_p/
# Failed to fetch https://www.zillow.com/tn/25_p/ - Status code: 400
# No listings returned for Tennessee on page 25. Moving to next state.
#
# --- Scraping listings for state: Texas ---
# Fetching URL: https://www.zillow.com/tx/
# Total listings collected so far: 1025
# Fetching URL: https://www.zillow.com/tx/2_p/
# Total listings collected so far: 1066
# Fetching URL: https://www.zillow.com/tx/3_p/
# Total listings collected so far: 1107
# Fetching URL: https://www.zillow.com/tx/4_p/
# Total listings collected so far: 1148
# Fetching URL: https://www.zillow.com/tx/5_p/
# Total listings collected so far: 1189
# Fetching URL: https://www.zillow.com/tx/6_p/
# Total listings collected so far: 1230
# Fetching URL: https://www.zillow.com/tx/7_p/
# Total listings collected so far: 1271
# Fetching URL: https://www.zillow.com/tx/8_p/
# Total listings collected so far: 1312
# Fetching URL: https://www.zillow.com/tx/9_p/
# Total listings collected so far: 1353
# Fetching URL: https://www.zillow.com/tx/10_p/
# Total listings collected so far: 1394
# Fetching URL: https://www.zillow.com/tx/11_p/
# Total listings collected so far: 1435
# Fetching URL: https://www.zillow.com/tx/12_p/
# Total listings collected so far: 1476
# Fetching URL: https://www.zillow.com/tx/13_p/
# Total listings collected so far: 1517
# Fetching URL: https://www.zillow.com/tx/14_p/
# Total listings collected so far: 1558
# Fetching URL: https://www.zillow.com/tx/15_p/
# Total listings collected so far: 1599
# Fetching URL: https://www.zillow.com/tx/16_p/
# Total listings collected so far: 1640
# Fetching URL: https://www.zillow.com/tx/17_p/
# Total listings collected so far: 1681
# Fetching URL: https://www.zillow.com/tx/18_p/
# Total listings collected so far: 1722
# Fetching URL: https://www.zillow.com/tx/19_p/
# Total listings collected so far: 1763
# Fetching URL: https://www.zillow.com/tx/20_p/
# Total listings collected so far: 1804
# Fetching URL: https://www.zillow.com/tx/21_p/
# Total listings collected so far: 1845
# Fetching URL: https://www.zillow.com/tx/22_p/
# Total listings collected so far: 1886
# Fetching URL: https://www.zillow.com/tx/23_p/
# Total listings collected so far: 1927
# Fetching URL: https://www.zillow.com/tx/24_p/
# Total listings collected so far: 1968
# Fetching URL: https://www.zillow.com/tx/25_p/
# Failed to fetch https://www.zillow.com/tx/25_p/ - Status code: 400
# No listings returned for Texas on page 25. Moving to next state.
#
# --- Scraping listings for state: Arkansas ---
# Fetching URL: https://www.zillow.com/ar/
# Total listings collected so far: 2009
# Fetching URL: https://www.zillow.com/ar/2_p/
# Total listings collected so far: 2050
# Fetching URL: https://www.zillow.com/ar/3_p/
# Total listings collected so far: 2091
# Fetching URL: https://www.zillow.com/ar/4_p/
# Total listings collected so far: 2132
# Fetching URL: https://www.zillow.com/ar/5_p/
# Total listings collected so far: 2173
# Fetching URL: https://www.zillow.com/ar/6_p/
# Total listings collected so far: 2214
# Fetching URL: https://www.zillow.com/ar/7_p/
# Total listings collected so far: 2255
# Fetching URL: https://www.zillow.com/ar/8_p/
# Total listings collected so far: 2296
# Fetching URL: https://www.zillow.com/ar/9_p/
# Total listings collected so far: 2337
# Fetching URL: https://www.zillow.com/ar/10_p/
# Total listings collected so far: 2378
# Fetching URL: https://www.zillow.com/ar/11_p/
# Total listings collected so far: 2419
# Fetching URL: https://www.zillow.com/ar/12_p/
# Total listings collected so far: 2460
# Fetching URL: https://www.zillow.com/ar/13_p/
# Total listings collected so far: 2501
# Fetching URL: https://www.zillow.com/ar/14_p/
# Total listings collected so far: 2542
# Fetching URL: https://www.zillow.com/ar/15_p/
# Total listings collected so far: 2583
# Fetching URL: https://www.zillow.com/ar/16_p/
# Total listings collected so far: 2624
# Fetching URL: https://www.zillow.com/ar/17_p/
# Total listings collected so far: 2665
# Fetching URL: https://www.zillow.com/ar/18_p/
# Total listings collected so far: 2706
# Fetching URL: https://www.zillow.com/ar/19_p/
# Total listings collected so far: 2747
# Fetching URL: https://www.zillow.com/ar/20_p/
# Total listings collected so far: 2788
# Fetching URL: https://www.zillow.com/ar/21_p/
# Total listings collected so far: 2829
# Fetching URL: https://www.zillow.com/ar/22_p/
# Total listings collected so far: 2870
# Fetching URL: https://www.zillow.com/ar/23_p/
# Total listings collected so far: 2911
# Fetching URL: https://www.zillow.com/ar/24_p/
# Total listings collected so far: 2952
# Fetching URL: https://www.zillow.com/ar/25_p/
# Failed to fetch https://www.zillow.com/ar/25_p/ - Status code: 400
# No listings returned for Arkansas on page 25. Moving to next state.
#
# --- Scraping listings for state: Mississippi ---
# Fetching URL: https://www.zillow.com/ms/
# Total listings collected so far: 2993
# Fetching URL: https://www.zillow.com/ms/2_p/
# Total listings collected so far: 3034
# Fetching URL: https://www.zillow.com/ms/3_p/
# Total listings collected so far: 3075
# Fetching URL: https://www.zillow.com/ms/4_p/
# Total listings collected so far: 3116
# Fetching URL: https://www.zillow.com/ms/5_p/
# Total listings collected so far: 3157
# Fetching URL: https://www.zillow.com/ms/6_p/
# Total listings collected so far: 3198
# Fetching URL: https://www.zillow.com/ms/7_p/
# Total listings collected so far: 3239
# Fetching URL: https://www.zillow.com/ms/8_p/
# Total listings collected so far: 3280
# Fetching URL: https://www.zillow.com/ms/9_p/
# Total listings collected so far: 3321
# Fetching URL: https://www.zillow.com/ms/10_p/
# Total listings collected so far: 3362
# Fetching URL: https://www.zillow.com/ms/11_p/
# Total listings collected so far: 3403
# Fetching URL: https://www.zillow.com/ms/12_p/
# Total listings collected so far: 3444
# Fetching URL: https://www.zillow.com/ms/13_p/
# Total listings collected so far: 3485
# Fetching URL: https://www.zillow.com/ms/14_p/
# Total listings collected so far: 3526
# Fetching URL: https://www.zillow.com/ms/15_p/
# Total listings collected so far: 3567
# Fetching URL: https://www.zillow.com/ms/16_p/
# Total listings collected so far: 3608
# Fetching URL: https://www.zillow.com/ms/17_p/
# Total listings collected so far: 3649
# Fetching URL: https://www.zillow.com/ms/18_p/
# Total listings collected so far: 3690
# Fetching URL: https://www.zillow.com/ms/19_p/
# Total listings collected so far: 3731
# Fetching URL: https://www.zillow.com/ms/20_p/
# Total listings collected so far: 3772
# Fetching URL: https://www.zillow.com/ms/21_p/
# Total listings collected so far: 3813
# Fetching URL: https://www.zillow.com/ms/22_p/
# Total listings collected so far: 3854
# Fetching URL: https://www.zillow.com/ms/23_p/
# Total listings collected so far: 3895
# Fetching URL: https://www.zillow.com/ms/24_p/
# Total listings collected so far: 3936
# Fetching URL: https://www.zillow.com/ms/25_p/
# Failed to fetch https://www.zillow.com/ms/25_p/ - Status code: 400
# No listings returned for Mississippi on page 25. Moving to next state.
#
# --- Scraping listings for state: Louisiana ---
# Fetching URL: https://www.zillow.com/la/
# Total listings collected so far: 3977
# Fetching URL: https://www.zillow.com/la/2_p/
# Total listings collected so far: 4018
# Fetching URL: https://www.zillow.com/la/3_p/
# Total listings collected so far: 4059
# Fetching URL: https://www.zillow.com/la/4_p/
# Total listings collected so far: 4100
# Fetching URL: https://www.zillow.com/la/5_p/
# Total listings collected so far: 4141
# Fetching URL: https://www.zillow.com/la/6_p/
# Total listings collected so far: 4182
# Fetching URL: https://www.zillow.com/la/7_p/
# Total listings collected so far: 4223
# Fetching URL: https://www.zillow.com/la/8_p/
# Total listings collected so far: 4264
# Fetching URL: https://www.zillow.com/la/9_p/
# Total listings collected so far: 4305
# Fetching URL: https://www.zillow.com/la/10_p/
# Total listings collected so far: 4346
# Fetching URL: https://www.zillow.com/la/11_p/
# Total listings collected so far: 4387
# Fetching URL: https://www.zillow.com/la/12_p/
# Total listings collected so far: 4428
# Fetching URL: https://www.zillow.com/la/13_p/
# Total listings collected so far: 4469
# Fetching URL: https://www.zillow.com/la/14_p/
# Total listings collected so far: 4510
# Fetching URL: https://www.zillow.com/la/15_p/
# Total listings collected so far: 4551
# Fetching URL: https://www.zillow.com/la/16_p/
# Total listings collected so far: 4592
# Fetching URL: https://www.zillow.com/la/17_p/
# Total listings collected so far: 4633
# Fetching URL: https://www.zillow.com/la/18_p/
# Total listings collected so far: 4674
# Fetching URL: https://www.zillow.com/la/19_p/
# Total listings collected so far: 4715
# Fetching URL: https://www.zillow.com/la/20_p/
# Total listings collected so far: 4756
# Fetching URL: https://www.zillow.com/la/21_p/
# Total listings collected so far: 4797
# Fetching URL: https://www.zillow.com/la/22_p/
# Total listings collected so far: 4838
# Fetching URL: https://www.zillow.com/la/23_p/
# Total listings collected so far: 4879
# Fetching URL: https://www.zillow.com/la/24_p/
# Total listings collected so far: 4920
# Fetching URL: https://www.zillow.com/la/25_p/
# Failed to fetch https://www.zillow.com/la/25_p/ - Status code: 400
# No listings returned for Louisiana on page 25. Moving to next state.
#
# --- Scraping listings for state: Alabama ---
# Fetching URL: https://www.zillow.com/al/
# Total listings collected so far: 4961
# Fetching URL: https://www.zillow.com/al/2_p/
# Total listings collected so far: 5002
# Fetching URL: https://www.zillow.com/al/3_p/
# Total listings collected so far: 5043
# Fetching URL: https://www.zillow.com/al/4_p/
# Total listings collected so far: 5084
# Fetching URL: https://www.zillow.com/al/5_p/
# Total listings collected so far: 5125
# Fetching URL: https://www.zillow.com/al/6_p/
# Total listings collected so far: 5166
# Fetching URL: https://www.zillow.com/al/7_p/
# Total listings collected so far: 5207
# Fetching URL: https://www.zillow.com/al/8_p/
# Total listings collected so far: 5248
# Fetching URL: https://www.zillow.com/al/9_p/
# Total listings collected so far: 5289
# Fetching URL: https://www.zillow.com/al/10_p/
# Total listings collected so far: 5330
# Fetching URL: https://www.zillow.com/al/11_p/
# Total listings collected so far: 5371
# Fetching URL: https://www.zillow.com/al/12_p/
# Total listings collected so far: 5412
# Fetching URL: https://www.zillow.com/al/13_p/
# Total listings collected so far: 5453
# Fetching URL: https://www.zillow.com/al/14_p/
# Total listings collected so far: 5494
# Fetching URL: https://www.zillow.com/al/15_p/
# Total listings collected so far: 5535
# Fetching URL: https://www.zillow.com/al/16_p/
# Total listings collected so far: 5576
# Fetching URL: https://www.zillow.com/al/17_p/
# Total listings collected so far: 5617
# Fetching URL: https://www.zillow.com/al/18_p/
# Total listings collected so far: 5658
# Fetching URL: https://www.zillow.com/al/19_p/
# Total listings collected so far: 5699
# Fetching URL: https://www.zillow.com/al/20_p/
# Total listings collected so far: 5740
# Fetching URL: https://www.zillow.com/al/21_p/
# Total listings collected so far: 5781
# Fetching URL: https://www.zillow.com/al/22_p/
# Total listings collected so far: 5822
# Fetching URL: https://www.zillow.com/al/23_p/
# Total listings collected so far: 5863
# Fetching URL: https://www.zillow.com/al/24_p/
# Total listings collected so far: 5904
# Fetching URL: https://www.zillow.com/al/25_p/
# Failed to fetch https://www.zillow.com/al/25_p/ - Status code: 400
# No listings returned for Alabama on page 25. Moving to next state.
#
# Collected 5904 listings in total.

# %%
# -----------------------------
# 6. Save the Extracted Data to CSV
# -----------------------------
csv_filename = "zillow_listings.csv"
df = pd.DataFrame(extracted_data)
df.to_csv(csv_filename, index=False)
print(f"Saved extracted data to {csv_filename}")
# Out:
# Saved extracted data to zillow_listings.csv

# %%
df.head()
# Out:
#         price                                        address  \
# 0    $398,900        181 Lakeview Trl, McMinnville, TN 37110
# 1    $650,000             151 John D St, La Vergne, TN 37086
# 2    $419,995         3336 Quail Run Ct, Nashville, TN 37214
# 3  $4,100,000  1772 Lockertsville Rd, Ashland City, TN 37015
# 4    $999,999       2123 Jc Taber Ln, Murfreesboro, TN 37130
#
#            addressStreet zipcode          city state   latitude  longitude  \
# 0       181 Lakeview Trl   37110   McMinnville    TN  35.696360 -85.823540
# 1          151 John D St   37086     La Vergne    TN  35.997270 -86.567730
# 2      3336 Quail Run Ct   37214     Nashville    TN  36.135098 -86.633286
# 3  1772 Lockertsville Rd   37015  Ashland City    TN  36.330610 -87.095604
# 4       2123 Jc Taber Ln   37130  Murfreesboro    TN  35.875940 -86.345085
#
#    bathrooms  bedrooms  livingArea       homeType homeStatus  daysOnZillow  \
# 0        3.0       3.0      2756.0  SINGLE_FAMILY   FOR_SALE             1
# 1        4.0       4.0      3999.0  SINGLE_FAMILY   FOR_SALE             1
# 2        4.0       3.0      2329.0  SINGLE_FAMILY   FOR_SALE             0
# 3        5.0       5.0      7901.0  SINGLE_FAMILY   FOR_SALE             4
# 4        4.0       5.0      3454.0  SINGLE_FAMILY   FOR_SALE             6
#
#    isFeatured  timeOnZillow  isZillowOwned brokerName  lotAreaValue  \
# 0       False     138767000          False       None          2.00
# 1       False      89395000          False       None          0.46
# 2       False      52367000          False       None          0.31
# 3       False     397967000          False       None         46.01
# 4       False     570767000          False       None          5.17
#
#   lotAreaUnit
# 0       acres
# 1       acres
# 2       acres
# 3       acres
# 4       acres
